# %%
from scipy import array
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
import astropy.constants as c
from analyseFunc import *

# %config InlineBackend.figure_formats = ['svg']

# %%
cat Grid1-models.txt
# Out:
# Grid1
# ...
# GridVar1:Vs_km               20                  ----30                  1                   log:False
# GridVar2:nH_init             4                   ----5                   1                   log:True
# ...
# FixedVars:           shock_type: C                   Bbeta: 3                   Zeta: 3.7e-15             timeJ: 5000                duration_max: 10000
# ...
# model               Vs_km               nH_init
# Grid1-0000          2.00E+01            1.00E+04
# Grid1-0001          2.10E+01            1.00E+04
# Grid1-0002          2.20E+01            1.00E+04
# Grid1-0003          2.30E+01            1.00E+04
# Grid1-0004          2.40E+01            1.00E+04
# Grid1-0005          2.50E+01            1.00E+04
# Grid1-0006          2.60E+01            1.00E+04
# Grid1-0007          2.70E+01            1.00E+04
# Grid1-0008          2.80E+01            1.00E+04
# Grid1-0009          2.90E+01            1.00E+04
# Grid1-0010          3.00E+01            1.00E+04
# ...

# %%
dir0000 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0000'
model000 = singleModel(dir0000,'$V_S$', r'$n_{\rm H}$', 20, 10000)
model000.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model000.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.58702 42.93852 42.18166 40.0056  38.30829 34.88368 32.06052]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [27.76074 26.65421 26.41356 25.48139 25.36061 25.418   25.31837 25.1658 ]
# [12095.24 12550.5  13150.72 13890.7 ] [24.13738 23.96318 23.8636  23.74624]

# %%
dir0001 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0001'
model001 = singleModel(dir0001,'$V_S$', r'$n_{\rm H}$', 21, 10000)
model001.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model001.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.5564  42.98182 42.27164 40.20922 38.65767 35.41169 32.77256]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [28.40848 27.26779 27.04431 25.87858 25.41739 25.45206 25.35577 25.19417]
# [12095.24 12550.5  13150.72 13890.7 ] [24.36098 24.07082 23.96148 23.8076 ]

# %%
dir0002 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0002'
model002 = singleModel(dir0002,'$V_S$', r'$n_{\rm H}$', 22, 10000)
model002.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
dir0005 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0005'
model005 = singleModel(dir0005,'$V_S$', r'$n_{\rm H}$', 25, 10000)
model005.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model005.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.51734 43.1995  42.5423  40.83757 39.63749 36.9656  34.88591]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [30.37825 29.3041  29.19617 27.85434 26.01059 25.6352  25.47198 25.28214]
# [12095.24 12550.5  13150.72 13890.7 ] [26.17818 25.15489 25.19246 24.36282]

# %%
dir0010 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0010'
model010 = singleModel(dir0010,'$V_S$', r'$n_{\rm H}$', 30, 10000)
model010.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model010.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.41828 43.33645 42.66097 41.38058 40.43398 38.42369 36.74625]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [32.24219 31.38512 31.29975 30.21077 28.15625 27.01842 26.54813 25.85706]
# [12095.24 12550.5  13150.72 13890.7 ] [28.62201 27.58554 27.69664 26.5505 ]

# %%
dir0011 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0011'
model011 = singleModel(dir0011,'$V_S$', r'$n_{\rm H}$', 20, 100000)
model011.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model011.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]])

# %%
dir0016 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0016'
model016 = singleModel(dir0016,'$V_S$', r'$n_{\rm H}$', 25, 100000)
model016.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model016.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [45.31394 43.40018 43.7474  41.70243 42.14586 39.76754 40.02865]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [34.45253 32.7467  33.85323 31.98758 31.57566 29.02838 29.28148 26.84498]
# [12095.24 12550.5  13150.72 13890.7 ] [30.61628 28.68728 29.88002 27.75985]

# %%
dir0021 = '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/output/Grid1-0021'
model021 = singleModel(dir0021,'$V_S$', r'$n_{\rm H}$', 30, 100000)
model021.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model021.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]])

# %%
cd ../..
# Out:
# /Users/dengyw/Workspace/Shock_1.1_rev122/Grid1

# %%
ls
# Out:
# Grid-2-output/           Grid2-models.txt         analyseFunc.py
# Grid-2-output.tar        PartFunc.py              output/
# Grid-dV1-dn1-models.txt  Untitled.ipynb
# Grid1-models.txt         __pycache__/

# %%
cat Grid2-models.txt
# Out:
# Grid2
# ...
# GridVar1:Vs_km               20                  ----30                  5                   log:False
# GridVar2:nH_init             3.6989700043360187  ----4.698970004336019   1                   log:True
# ...
# FixedVars:           shock_type: C                   Bbeta: 3                   Zeta: 3.7e-15             timeJ: 5000                duration_max: 10000
# ...
# model               Vs_km               nH_init
# Grid2-0000          2.00E+01            5.00E+03
# Grid2-0001          2.50E+01            5.00E+03
# Grid2-0002          3.00E+01            5.00E+03
# Grid2-0003          2.00E+01            5.00E+04
# Grid2-0004          2.50E+01            5.00E+04
# Grid2-0005          3.00E+01            5.00E+04

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid-2-output/Grid2-0001'
model = singleModel(dirc,'$V_S$', r'$n_{\rm H}$', 25, 5000)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.14532 42.96428 42.09814 40.26141 38.54369 35.60755 32.95461]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [29.48882 28.48369 28.1784  26.92879 25.17469 24.96797 24.83224 24.65209]
# [12095.24 12550.5  13150.72 13890.7 ] [25.12296 24.28357 24.17239 23.58108]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid-2-output/Grid2-0002'
model = singleModel(dirc,'$V_S$', r'$n_{\rm H}$', 30, 5000)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.13968 43.13834 42.31536 40.92879 39.55542 37.26103 35.05111]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [31.39949 30.58967 30.32512 29.2783  27.07706 26.14567 25.67438 25.18205]
# [12095.24 12550.5  13150.72 13890.7 ] [27.60129 26.64435 26.59961 25.5707 ]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid-2-output/Grid2-0004'
model = singleModel(dirc,'$V_S$', r'$n_{\rm H}$', 25, 50000)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [45.11239 43.41693 43.43361 41.57882 41.58254 39.25628 38.84002]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [33.02566 31.58398 32.27498 30.62768 29.19345 27.16272 26.99465 25.92788]
# [12095.24 12550.5  13150.72 13890.7 ] [29.20083 27.51174 28.33128 26.48584]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid-2-output/Grid2-0005'
model = singleModel(dirc,'$V_S$', r'$n_{\rm H}$', 30, 50000)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.83323 43.5588  43.32802 41.96195 41.86013 40.16255 39.87275]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [34.73111 33.61706 34.16864 32.91334 31.95352 30.08987 29.89299 27.90786]
# [12095.24 12550.5  13150.72 13890.7 ] [31.42272 30.09076 30.7578  29.25624]

# %%
cat Grid4-models.txt
# Out:
# Grid4
# ...
# GridVar1:Vs_km               30                  ----37                  7                   log:False
# GridVar2:Zeta                -17.0               -----14.0               1                   log:True
# ...
# FixedVars:           shock_type: C                   Bbeta: 3                   n_init: 6000                timeJ: 3000                duration_max: 6000
# ...
# model               Vs_km               Zeta
# Grid4-0000          3.00E+01            1.00E-17
# Grid4-0001          3.70E+01            1.00E-17
# Grid4-0002          3.00E+01            1.00E-16
# Grid4-0003          3.70E+01            1.00E-16
# Grid4-0004          3.00E+01            1.00E-15
# Grid4-0005          3.70E+01            1.00E-15
# Grid4-0006          3.00E+01            1.00E-14
# Grid4-0007          3.70E+01            1.00E-14

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Gr

# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [33.15812 32.54526 32.31336 31.52292 29.62919 28.60103 28.02611 26.98526]
# [12095.24 12550.5  13150.72 13890.7 ] [29.95816 29.19562 29.16183 28.29472]

# %%
cd ../..
# Out:
# /Users/dengyw/Workspace/Shock_1.1_rev122/Grid1

# %%
cat Grid5-models.txt
# Out:
# Grid5
# ...
# GridVar1:Vs_km               35                  ----50                  5                   log:False
# GridVar2:Zeta                -15.431798275933005 -----13.431798275933005 1                   log:True
# ...
# FixedVars:           shock_type: C                   Bbeta: 3                   n_init: 6000                timeJ: 3000                duration_max: 6000
# ...
# model               Vs_km               Zeta
# Grid5-0000          3.50E+01            3.70E-16
# Grid5-0001          4.00E+01            3.70E-16
# Grid5-0002          4.50E+01            3.70E-16
# Grid5-0003          5.00E+01            3.70E-16
# Grid5-0004          3.50E+01            3.70E-15
# Grid5-0005          4.00E+01            3.70E-15
# Grid5-0006          4.50E+01            3.70E-15
# Grid5-0007          5.00E+01            3.70E-15
# Grid5-0008          3.50E+01            3.70E-14
# Grid5-0009          4.00E+01            3.70E-14
# Grid5-0010          4.50E+01            3.70E-14
# ...

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid5-output/Grid5-0004'
model = singleModel(dirc,'$V_S$', r'$Zeta$', 35, -15)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.30418 43.37007 42.65427 41.64136 40.81107 39.32357 37.95122]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [33.77982 33.1619  33.02504 32.24517 30.47164 29.37656 28.84057 27.67548]
# [12095.24 12550.5  13150.72 13890.7 ] [30.68984 29.91566 29.95455 29.06314]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid5-output/Grid5-0005'
model = singleModel(dirc,'$V_S$', r'$Zeta$', 40, -15)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.24668 43.3398  42.6278  41.74197 41.00093 39.81799 38.68564]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [34.86912 34.39516 34.25241 33.65661 32.13592 31.1983  30.67796 29.58251]
# [12095.24 12550.5  13150.72 13890.7 ] [32.14024 31.55236 31.54955 30.85702]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid5-output/Grid5-0006'
model = singleModel(dirc,'$V_S$', r'$Zeta$', 45, -15)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [44.16871 43.29851 42.59454 41.77853 41.09245 40.08759 39.12978]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [35.61522 35.22028 35.09403 34.60146 33.30512 32.48249 31.98271 30.99085]
# [12095.24 12550.5  13150.72 13890.7 ] [33.1276  32.64946 32.63264 32.06465]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid5-output/Grid5-0008'
model = singleModel(dirc,'$V_S$', r'$Zeta$', 35, -14)
model.plot_H2_emissivity_vs_Tn(lines = ['0-0S(5)','1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [0.1,1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [43.71964 42.78017 42.05933 41.26359 40.33014 39.16064 37.78363]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [35.297   34.85832 34.55753 33.97889 32.17037 31.25852 30.58756 29.57036]
# [12095.24 12550.5  13150.72 13890.7 ] [32.35297 31.83555 31.67575 31.04446]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid5-output/Grid5-0009'
model = singleModel(dirc,'$V_S$', r'$Zeta$', 40, -14)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [43.72578 42.79591 42.09722 41.35241 40.50559 39.48228 38.29535]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [35.93937 35.54839 35.29212 34.78254 33.20182 32.37575 31.76476 30.77523]
# [12095.24 12550.5  13150.72 13890.7 ] [33.2416  32.7884  32.6576  32.10235]

# %%
dirc= '/Users/dengyw/Workspace/Shock_1.1_rev122/Grid1/Grid5-output/Grid5-0011'
model = singleModel(dirc,'$V_S$', r'$Zeta$', 40, -14)
model.plot_H2_emissivity_vs_Tn(lines = ['1-0S(2)','1-0S(1)','1-0S(0)','2-1S(1)'], magFac = [1,1,1,20])

# %%
model.plot_population_diagram(v_levels = [0,1,2], J_levels = [[2,3,4,5,6,7,8],[2,3,4,5,8,9,10,11], [2,3,4,5]], log10 = True, Fit = True)
# Out:
# [ 509.85  1015.153 1681.678 2503.87  3474.434 4586.377 5829.758] [43.46929 42.73815 42.06919 41.38549 40.63644 39.79141 38.85369]
# [ 6471.607  6951.587  7584.601  8365.297 11521.83  12817.52  14221.11
#  15722.29 ] [36.78442 36.46453 36.26894 35.85913 34.62252 33.94676 33.44588 32.58366]
# [12095.24 12550.5  13150.72 13890.7 ] [34.44647 34.09536 33.99628 33.56369]
